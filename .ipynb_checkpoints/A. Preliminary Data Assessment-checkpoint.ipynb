# %% [markdown]
# ## MMTHE01 - Masters Thesis

# %% [markdown]
# ### A. Preliminary Data Assessment
# * Importing the dataset
# * Initial Analysis on the dataset
# * Feature Engineering

# %% [markdown]
# #### Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os

from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# #### Set working directory

# %%
# Check your current working directory
cwd = os.getcwd()

# Define your relative path
relative_path = r"Analysis Files"  # adjust this relative to cwd

# Build the full path
full_path = os.path.join(cwd, relative_path)

# Check if it exists before changing
if os.path.exists(full_path):
    os.chdir(full_path)
    print("Changed directory to:", full_path)
else:
    print("Folder does not exist:", full_path)
# Out:
# Changed directory to: C:\Users\eaber\Documents\12. Master Thesis Final\Analysis Files
